# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from VideoAgent import VideoAgent, Typography, BackgroundPlates, Layout, Anim, Subtitles

agent = VideoAgent(
    typography=Typography(
        font="Inter-Bold",     # шрифт
        title_size=96,         # РОЗМІР ЗАГОЛОВКА
        subtitle_size=56,      # РОЗМІР ПІДЗАГОЛОВКА
        title_color="gray",
        subtitle_color="black",
        stroke_color="#111111",
        stroke_width=1,
        title_method = "caption",     # labal для того щоб не переносилось
        subtitle_method = "caption"
    ),
    plates=BackgroundPlates(
        enabled=True,          # ← «ґрунт/плашка»: вкл/викл
        opacity=0.6,           # прозорість
        padding_left=40, padding_right=40,
        padding_top=28, padding_bottom=16,
        title_radius=24, subtitle_radius=18,
    ), 
    layout=Layout(
        size=(1280, 720),     # портретне відео (Reels/Shorts)
        title_left_margin=0.08,
        subtitle_left_margin=0.08,
        subtitle_bottom_margin=0.09,
        subtitle_width_ratio=0.70,  # ширина колонки підзаголовка
    ),
    anim=Anim(
        intro_fade=1.2,
        outro_start=-2.5,
        outro_fade=1.4,
    ),
)

agent.create_into_video(
    image_path="/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/Intro.png",
    text_blocks=["AML Uncovered", "Foundations of AML: Key Concepts and Definitions"],
    audio_path="/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/module1/video1/audio_out/Slide_1_000_Intro.mp3",
    output_path="intro.mp4",
    subtitles=Subtitles(text="Welcome to AML Uncovered. Today's lecture covers core AML principles, definitions of money laundering stages, and how institutions classify risk. In Course: AML Uncovered, Module 1: AML Foundations Refresher (Bridge Module), we illustrate practical examples of how criminals attempt to conceal illicit funds and how compliance teams identify early warning signs, and this session reinforces the foundation needed for intermediate, application-focused learning.", burn_in=False),
)


# agent.typography.title_size = 50
agent.typography.title_method = "label"  ##для того щоб не переносити по рядкам
agent.create_outro_video(
    image_path="/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/Outro.png",
    text_blocks=["Thank you!", "See you on next lecture"],
    output_path="outro.mp4",
    duration=6.0,                 # рівно стільки триватиме відео
    create_empty_srt=True,        # створить пустий SRT
)

agent.create_video_bulleted_sequence(
    image_path="/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/module1/video1/image_out/Slide_2.png",
    title_text="AGENDA",
    title_audio_path="/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/module1/video1/audio_out/Slide_2_000_Intro.mp3",
    title_subs_text="Moving forward, let's focus on the core themes and why they matter for practical AML. These clusters guide how we organize risk, detection, and processes.",
    bullets=[
        {"text": "Core concepts",  
             "audio": "/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/module1/video1/audio_out/Slide_2_Bullet_001.mp3", 
             "subs": "These concepts anchor our understanding of money laundering and regulatory expectations, helping teams decide where to focus controls"},
        {"text": "Risk classification", 
             "audio": "/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/module1/video1/audio_out/Slide_2_Bullet_002.mp3", 
             "subs": "Risk classification helps prioritize actions. It combines customer, product, geography, and behavior to assign intensity"},
        {"text": "Stages of laundering",  
             "audio": "/Users/vyklyuk/Documents/Vykladannya/IBM/Complience/Agent_Course_Creation/output/AML_Uncovered/module1/video1/audio_out/Slide_2_Bullet_004.mp3", 
             "subs": "Money laundering stages clarify where to apply monitoring, from onboarding to ongoing transactions"},
    ],
    output_path="slide.mp4",
    burn_subtitles=False,   # True, якщо хочеш підпалити субтитри
)
# Out:
# ImageMagick (fallback): /opt/homebrew/bin/convert
# Субтитри збережено: video_out/intro.srt
# Починаємо рендеринг відео...
# Moviepy - Building video video_out/intro.mp4.
# MoviePy - Writing audio in introTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video video_out/intro.mp4
# Moviepy - Done !
# Moviepy - video ready video_out/intro.mp4
# Відео успішно збережено: video_out/intro.mp4
# Порожній SRT збережено: video_out/outro.srt
# Починаємо рендеринг відео (без звуку)...
# Moviepy - Building video video_out/outro.mp4.
# Moviepy - Writing video video_out/outro.mp4
# Moviepy - Done !
# Moviepy - video ready video_out/outro.mp4
# Відео успішно збережено: video_out/outro.mp4
# SRT збережено: video_out/slide.srt
# Починаємо рендеринг відео з булетами...
# Moviepy - Building video video_out/slide.mp4.
# MoviePy - Writing audio in slideTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video video_out/slide.mp4
# Moviepy - Done !
# ...
